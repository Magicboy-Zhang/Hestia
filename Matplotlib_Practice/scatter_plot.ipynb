# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1, 3, 3, 4, 6, 8, 9])
y = np.array([0, 3, 5, 5, 7, 7, 8])

fig = plt.figure(figsize = (6, 6))
ax = fig.add_subplot(111)

ax.scatter(x = x, y = y)

plt.show()
